# %% [markdown]
# #  Pima Indians Diabetes Database Descriptive Statistics Project

# %% [markdown]
# ## Introduction To Dataset

# %% [markdown]
# Predict the onset of diabetes based on diagnostic measures. This dataset is originally from the National Institute of Diabetes
# and Digestive and Kidney Diseases. The objective of the dataset is to diagnostically predict whether a patient has diabetes,
# based on certain diagnostic measurements included in the dataset.

# %% [markdown]
# ## Variables of the dataset
#
# **Pregnancies**: Number of times pregnant
#
# **Glucose**: Plasma glucose concentration 2 hours in an oral glucose tolerance test
#
# **Blood Pressure**: Diastolic blood pressure (mm Hg)
#
# **Skin Thickness**: Triceps skin fold thickness (mm)
#
# **Insulin**: 2-Hour serum insulin (mu U/ml)
#
# **BMI**: Body mass index (weight in kg/(height in m)^2)
#
# **Diabetes Pedigree Function**: Diabetes pedigree function
#
# **Age**: Age (years)
#
# **Outcome**: Class variable (0 or 1) 0 mean non-diabetic and 1 means diabetic

# %% [markdown]
# ## Understanding of dataset

# %% [markdown]
# In this dataset, the term Diabetes Pedigree Function means it is function which scores likelihood of diabetes based on family history.
#
# Remaining variables are self explanatory.

# %% [markdown]
# ##  Important necessary libraries

# %%
import numpy as np  # for numerical calculation
import pandas as pd    # for analysis
import matplotlib.pyplot as plt  # for visualisation
import seaborn as sns   # for visualisation
# %matplotlib inline     
# Display output inline

# %%
import warnings      # to not show warnings
warnings.filterwarnings("ignore")    # ignore warnings

# %% [markdown]
# ## Reading  pima indians diabetes dataset

# %%
diabetic_data = pd.read_csv("diabetes.csv")  # reading csv file
diabetic_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### Q1. Please do the basic exploration of data and explain missing values, number of rows and columns and data types in statistical term.

# %%
# Basic information of data
diabetic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetic_data.isnull().sum()      # showing missing values in data
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# From the above information , there is no missing values in dataset.

# %%
# using this, get numer of columns and rows in the dataset
diabetic_data.shape
# Out:
# (768, 9)

# %% [markdown]
# In this dataset , 768 rows and 9 columns

# %% [markdown]
#  Following are data types of variables(columns) in this dataset

# %% [markdown]
# Data Types in Statastics
#
# Categoriacal/ Qualitative
#
# 1 Nominal --> Outcome
#
# Numerical/Quantitative
#
# 1 Discrete ---> Pregnancies
#
# 2 Continuous ---> Age , BloodPressure , Glucose ,SkinThickness , Diabetes Pedigree Function , insulin, BMI

# %% [markdown]
# ### Q2. Calculate appropriate measures of central tendency for Glucose and outcome column only?

# %% [markdown]
# For Glucose

# %%
sns.histplot(diabetic_data['Glucose'], kde=True)  # plot histogram
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Count'>

# %% [markdown]
# From above graph, Glucose Variable is skewed. So For skewed data , measure of central tendancy is median

# %%
diabetic_data.Glucose.median()   # find median
# Out:
# 117.0

# %% [markdown]
# For Outcome Variable

# %% [markdown]
# As Outcome variable is categoriacal in that nominal, So measure of central tendancy is mode

# %%
diabetic_data["Outcome"].mode()   # find mode
# Out:
# 0    0
# dtype: int64

# %% [markdown]
# ### Q3. Please provide 5 points data summaries for required columns?

# %%
diabetic_data.describe()  # show summary of data
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# 5 point data summary of dataset using describe() function
#
# here we get mean of the dataset ,minimum,maximum value, 25%,50%,75% th of values

# %% [markdown]
# ### Q4. Please create an appropriate plot to examine the relationship between Age and Glucose.

# %%
# Scatter plot because both variables are numrical , to get distribution
sns.scatterplot(x="Glucose", y="Age",data = diabetic_data)  # scatter plot
plt.title("Glucose Vs Age ")   # title
plt.xlabel('Plasma glucose concentration')   # xlabel
plt.ylabel('Age (years)')   # y label
# Out:
# Text(0, 0.5, 'Age (years)')

# %% [markdown]
# ### Q5. Please create an appropriate plot to see the distribution of Outcome variable?

# %%
 # calculated number of values counts in Outcome variable
diabetic_data["Outcome"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
# use of pie chart because of categorical data
label = [0 , 1]
sizes = [500, 268]
plt.pie(sizes,labels =label,autopct='%1.1f%%',shadow=True) #startangle=90)
plt.title("Pie Chart")
plt.show()

# %% [markdown]
# ### Q6. Please examine the distribution of numerical data and explain which variable normally distributed and which variable is         seems to be skewed. Please also tell the direction of skewness.

# %%
column = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
#list of numerical columns

# %%
for i in column:             # for loop for ploting histoplot list of variable
    fig, ax = plt.subplots(1,1, figsize=(10, 4))       # figure size of plots
    sns.histplot(diabetic_data[i],kde=True)     # histoplot
    plt.title('Distribution of %s'%(i), fontsize=25)   # give title
    plt.xlabel(i, fontsize=16)   # xlabel font size 
    plt.ylabel('Frequency', fontsize=16)  # y lable & font size

# %% [markdown]
# From the above  plot
# * **Normally Distributed Variables** - BMI, Glucose, Skin Thickness
# * **Skewed Variables** - Pregnancies, BloodPressure, DiabetesPedigreeFunction, Insulin, Age

# %% [markdown]
# **Direction of Skewness**
#  * **Right Skewed**  - Pregnancies,  DiabetesPedigreeFunction, Insulin, Age
#  * **Left Skewed** -  BloodPressure

# %% [markdown]
# ### Q7. Please calculate the skewness value and divide variables into symmetrical, moderately skewed and highly skewed

# %%
diabetic_data.skew()  # find skewness
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %% [markdown]
# #### Rules for Skewness:
#
# * If skewness is less than -1 or greater than 1, the distribution is highly skewed.
# * If skewness is between -1 and -0.5 or between 0.5 and 1, the distribution is moderately skewed.
# * If skewness is between -0.5 and 0.5, the distribution is approximately symmetric.

# %% [markdown]
# #### Variables According to Skewness
# * **Symmetrical :** Glucose, BMI, Skinthickness
# * **Moderately Skewed :** Pregnancies, Outcome, Age
# * **Highly Skewed :**  BloodPressure, Insulin, DiabetesPedigreeFunction

# %% [markdown]
# ### Q8. Please create appropriate plot to examine the outliers of these variables. Please name the variables which have outliers.

# %%
fig, axes = plt.subplots(3, 3, figsize=(15, 12))    # fig size of subplots 
fig.suptitle('Examine the outliers of the variables', fontsize=25)  #title to plot
sns.boxplot(diabetic_data['Pregnancies'], ax=axes[0, 0])  # box plot at position row 0 and column 0
sns.boxplot(diabetic_data['Glucose'], ax=axes[0, 1])         # box plot at position row 0 and column 1
sns.boxplot(diabetic_data['BloodPressure'], ax=axes[0, 2])   # box plot at position row 0 and column 2
sns.boxplot(diabetic_data['SkinThickness'], ax=axes[1, 0])   # box plot at position row 1 and column 0
sns.boxplot(diabetic_data['Insulin'], ax=axes[1, 1])         # box plot at position row 1 and column 1
sns.boxplot(diabetic_data['BMI'], ax=axes[1, 2])           # box plot at position row 1 and column 2
sns.boxplot(diabetic_data['DiabetesPedigreeFunction'], ax=axes[2, 0])    # box plot at position row 2 and column 0
sns.boxplot(diabetic_data['Age'], ax=axes[2, 1])          # box plot at position row 2 and column 1
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# **Outliers :**  Abnormal observation far away from other observation

# %% [markdown]
#   **So thhe varibales containing outliers are:**
#
#   - Pregnencies
#   - Glucose
#   - SkinThickness
#   - BloodPressure
#   - Insulin
#   - BMI
#   - DiabetesPedigreeFunction
#   - Age

# %% [markdown]
# ### Q9. What should be the measures of central tendency and dispersion for skewed data?

# %% [markdown]
# * Measures of central tendency for skewed data  - **Median**
# * Measure of dispersion for skewed data  -  **IQR**

# %%
col = ['Pregnancies','BloodPressure','Insulin','DiabetesPedigreeFunction','Age']    # list of skewed variables

# %% [markdown]
# **Median**

# %%
diabetic_data[col].median()  # median
# Out:
# Pregnancies                  3.0000
# BloodPressure               72.0000
# Insulin                     30.5000
# DiabetesPedigreeFunction     0.3725
# Age                         29.0000
# dtype: float64

# %% [markdown]
# **IQR**

# %% [markdown]
# The interquartile range (IQR) is a measure of variability, based on dividing a data set into quartiles.

# %% [markdown]
# * **Q1**  = **25th percentile**
# * **Q2**  = **75th percentile**

# %%
q1 = diabetic_data[col].quantile(0.25)   # 25th percentile
q1
# Out:
# Pregnancies                  1.00000
# BloodPressure               62.00000
# Insulin                      0.00000
# DiabetesPedigreeFunction     0.24375
# Age                         24.00000
# Name: 0.25, dtype: float64

# %%
q3 = diabetic_data[col].quantile(0.75)   # # 75th percentile
q3
# Out:
# Pregnancies                   6.00000
# BloodPressure                80.00000
# Insulin                     127.25000
# DiabetesPedigreeFunction      0.62625
# Age                          41.00000
# Name: 0.75, dtype: float64

# %%
#interquartile range
IQR = q3  - q1           # find IQR
IQR
# Out:
# Pregnancies                   5.0000
# BloodPressure                18.0000
# Insulin                     127.2500
# DiabetesPedigreeFunction      0.3825
# Age                          17.0000
# dtype: float64

# %% [markdown]
# IQR values for all the variables containing skewed data.
